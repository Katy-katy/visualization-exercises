# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
mpl.rcParams['patch.force_edgecolor'] = True

# %%
df1 = pd.read_csv('df1',index_col=0) # we will use the first col as index since it is a timeserie
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
df1['A'].hist()

# %%
# we can import seaborn to have a more nice style:
import seaborn as sns

# %%
df1['A'].hist(bins=30)

# %%
df2.plot.area(alpha=0.4)

# %%
df2.plot.bar() # index should be categorical!!!!!

# %%
df2.plot.bar(stacked=True)

# %%
#Great for a timeserie!!!!
df1.plot.line(x=df1.index,y='B',figsize=(12,3),lw=1)

# %%
df1.plot.scatter(x='A',y='B')

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')

# %%
import matplotlib as mpl
mpl.rcParams['patch.force_edgecolor'] = True
df1.plot.scatter(x='A',y='B',s=df1['C']*200)
# Out:
# /Users/kate/anaconda/lib/python3.6/site-packages/matplotlib/collections.py:877: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box() # Can also pass a by= argument for groupby

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='Oranges')

# %%
df2['a'].plot.kde()

# %%
df2.plot.density()

# %% [markdown]
# ## Exercises

# %%
df3 = pd.read_csv('df3')
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.shape
# Out:
# (500, 4)

# %%
sns.set_style('ticks')
df3.plot.scatter(x='a',y='b', c='red',s=50,figsize=(12,3))

# %%
df3['a'].hist(bins=10)

# %%
plt.style.use('ggplot')
df3['a'].hist(bins=10)

# %%
df3[['a', 'b']].plot.box()

# %%
df2['d'].plot.kde()

# %%
df2['d'].plot.kde(lw = 5, ls = "--")

# %%
df3.loc[0:30].plot.area(alpha=0.4)

# %%
f = plt.figure()
df3.loc[0:30].plot.area(alpha=0.4,ax=f.gca())
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
